# %%
import pandas as pd

# %%
df=pd.read_csv('Uber.csv')
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df.shape
# Out:
# (1156, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
df.loc[0:3,['START_DATE*']]
# Out:
#       START_DATE*
# 0  1/1/2016 21:11
# 1   1/2/2016 1:25
# 2  1/2/2016 20:25
# 3  1/5/2016 17:31

# %%
df['START_DATE*'].dtype
# Out:
# dtype('O')

# %%
df.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
ndf = pd.read_csv(
    'Uber.csv',
    dtype={'MILES*': float},  # Read as float to avoid conversion error
    nrows=5,
    na_values=["NA", "Unknown", "Nan"]
)
ndf
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  5 non-null      object
#  1   END_DATE*    5 non-null      object
#  2   CATEGORY*    5 non-null      object
#  3   START*       5 non-null      object
#  4   STOP*        5 non-null      object
#  5   MILES*       5 non-null      float64
#  6   PURPOSE*     4 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 412.0+ bytes

# %%
df.iloc[20:40,0:3]
# Out:
#         START_DATE*        END_DATE* CATEGORY*
# 20  1/12/2016 15:13  1/12/2016 15:28  Business
# 21  1/12/2016 15:42  1/12/2016 15:54  Business
# 22  1/12/2016 16:02  1/12/2016 17:00  Business
# 23  1/13/2016 13:54  1/13/2016 14:07  Business
# 24  1/13/2016 15:00  1/13/2016 15:28  Business
# 25  1/14/2016 16:29  1/14/2016 17:05  Business
# 26  1/14/2016 21:39  1/14/2016 21:45  Business
# 27   1/15/2016 0:41   1/15/2016 1:01  Business
# 28  1/15/2016 11:43  1/15/2016 12:03  Business
# 29  1/15/2016 13:26  1/15/2016 13:44  Business
# 30  1/18/2016 14:55  1/18/2016 15:06  Business
# 31  1/18/2016 16:13  1/18/2016 16:24  Business
# 32   1/19/2016 9:09   1/19/2016 9:23  Business
# 33  1/19/2016 10:55  1/19/2016 11:09  Business
# 34  1/20/2016 10:36  1/20/2016 11:11  Business
# 35  1/20/2016 11:48  1/20/2016 12:19  Business
# 36  1/20/2016 13:25  1/20/2016 14:19  Business
# 37  1/21/2016 14:25  1/21/2016 14:29  Business
# 38  1/21/2016 14:43  1/21/2016 14:51  Business
# ...

# %%
df.iloc[-1:-5:-1,:]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155            Totals               NaN       NaN               NaN
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
#
#                  STOP*   MILES*        PURPOSE*
# 1155               NaN  12204.7             NaN
# 1154         Ilukwatta     48.2  Temporary Site
# 1153           Gampaha      6.4  Temporary Site
# 1152  Unknown Location     16.2         Meeting

# %%
temp=pd.DataFrame({
    'A':[1,2,3,4],
    'B':[10,20,30,40],
    'C':['2025-1-19','2025-1-21','2025-1-11','2025-1-22']
})
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int64
#  1   B       4 non-null      int64
#  2   C       4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
temp['C']=pd.to_datetime(temp['C'])
temp.info()
temp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int64
#  1   B       4 non-null      int64
#  2   C       4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 228.0 bytes
#    A   B          C
# 0  1  10 2025-01-19
# 1  2  20 2025-01-21
# 2  3  30 2025-01-11
# 3  4  40 2025-01-22

# %%
temp1=pd.DataFrame({
    'A':[1,2,3,4],
    'B':[10,20,30,40],
    'C':['19-1-2025','21-1-2025','11-1-2025','22-1-2025']
})
temp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int64
#  1   B       4 non-null      int64
#  2   C       4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
temp1['C']=pd.to_datetime(temp1['C'])
temp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int64
#  1   B       4 non-null      int64
#  2   C       4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 228.0 bytes
# C:\Users\CVR\AppData\Local\Temp\ipykernel_4760\3020879260.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   temp1['C']=pd.to_datetime(temp1['C'])

# %%
temp1.head()
# Out:
#    A   B          C
# 0  1  10 2025-01-19
# 1  2  20 2025-01-21
# 2  3  30 2025-01-11
# 3  4  40 2025-01-22

# %%
temp2=pd.DataFrame({
    'A':[1,2,3,4],
    'B':[10,20,30,40],
    'C':['19-1-2025','21-1-2025','11-1-2025','22-1-2025']
})
temp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int64
#  1   B       4 non-null      int64
#  2   C       4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
temp2['C']=pd.to_datetime(temp2['C'],format="%d-%m-%Y")
temp2.head()
# Out:
#    A   B          C
# 0  1  10 2025-01-19
# 1  2  20 2025-01-21
# 2  3  30 2025-01-11
# 3  4  40 2025-01-22

# %%
temp2['A']=temp2['A'].astype('string')

# %%
temp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      string
#  1   B       4 non-null      int64
#  2   C       4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), string(1)
# memory usage: 228.0 bytes

# %%
temp2['A']=temp2['A'].astype('float')

# %%
temp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       4 non-null      int64
#  2   C       4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 228.0 bytes

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df['START*'].nunique()
df['STOP*'].nunique()
# Out:
# 188

# %%
# displaying each start frequency
df['START*'].value_counts()
# Out:
# START*
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# Florence              1
# Ridgeland             1
# Daytona Beach         1
# Sky Lake              1
# Gampaha               1
# Name: count, Length: 177, dtype: int64

# %%
df.loc[df['MILES*']>50]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 232    3/17/2016 12:52   3/17/2016 15:11  Business            Austin
# 251    3/19/2016 19:33   3/19/2016 20:39  Business         Galveston
# 268    3/25/2016 13:24   3/25/2016 16:22  Business              Cary
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 295     4/2/2016 12:21    4/2/2016 14:47  Business         Kissimmee
# 296     4/2/2016 16:57    4/2/2016 18:09  Business     Daytona Beach
# 297     4/2/2016 19:38    4/2/2016 22:36  Business      Jacksonville
# 298     4/2/2016 23:11     4/3/2016 1:34  Business         Ridgeland
# 299      4/3/2016 2:00     4/3/2016 4:16  Business          Florence
# 546    7/14/2016 16:39   7/14/2016 20:05  Business       Morrisville
# 559    7/17/2016 12:20   7/17/2016 15:25  Personal             Boone
# ...

# %%
df.loc[(df['MILES*']>50) & (df['MILES*']<100)]
# Out:
#           START_DATE*         END_DATE* CATEGORY*            START*  \
# 4      1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 251   3/19/2016 19:33   3/19/2016 20:39  Business         Galveston
# 295    4/2/2016 12:21    4/2/2016 14:47  Business         Kissimmee
# 296    4/2/2016 16:57    4/2/2016 18:09  Business     Daytona Beach
# 707   8/24/2016 13:01   8/24/2016 15:25  Business  Unknown Location
# 710   8/25/2016 17:19   8/25/2016 19:20  Business  Unknown Location
# 726   8/27/2016 14:01   8/27/2016 15:44  Business            Lahore
# 751    9/6/2016 17:49    9/6/2016 17:49  Business  Unknown Location
# 871  10/28/2016 20:13  10/28/2016 22:00  Business         Asheville
# 873  10/29/2016 17:13  10/29/2016 19:19  Business        Hayesville
# 880  10/30/2016 13:24  10/30/2016 14:37  Business       Bryson City
#
#                 STOP*  MILES*        PURPOSE*
# 4     West Palm Beach    63.7  Customer Visit
# 251           Houston    57.0  Customer Visit
# ...

# %%
# dispaly new york city rows as start 
df.loc[df['START*']=='New York',['START*','START_DATE*']]
# Out:
#        START*      START_DATE*
# 10   New York  1/10/2016 15:08
# 22   New York  1/12/2016 16:02
# 106  New York  2/14/2016 16:35
# 423  New York  6/10/2016 15:19

# %%
# display miles between 50 and 100 ,print only start ,stop ,miles cols
df.loc[(df['MILES*']>50) & (df['MILES*']<100),['START*','STOP*','MILES*']]
# Out:
#                START*             STOP*  MILES*
# 4         Fort Pierce   West Palm Beach    63.7
# 251         Galveston           Houston    57.0
# 295         Kissimmee     Daytona Beach    77.3
# 296     Daytona Beach      Jacksonville    80.5
# 707  Unknown Location  Unknown Location    96.2
# 710  Unknown Location  Unknown Location    50.4
# 726            Lahore  Unknown Location    86.6
# 751  Unknown Location  Unknown Location    69.1
# 871         Asheville            Topton    91.8
# 873        Hayesville            Topton    75.7
# 880       Bryson City         Asheville    68.4

# %%
# df[df['START*']=='Unknown Location']

# %%
cities=['Fort Pierce','Galveston','Kissimmee']
df.loc[df['START*'].isin(cities)]
# Out:
#          START_DATE*        END_DATE* CATEGORY*       START*            STOP*  \
# 0     1/1/2016 21:11   1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1      1/2/2016 1:25    1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2     1/2/2016 20:25   1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3     1/5/2016 17:31   1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4     1/6/2016 14:42   1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
# 247  3/19/2016 17:17  3/19/2016 17:32  Business    Galveston     Port Bolivar
# 251  3/19/2016 19:33  3/19/2016 20:39  Business    Galveston          Houston
# 272  3/26/2016 15:19  3/26/2016 15:49  Personal    Kissimmee          Orlando
# 276  3/27/2016 15:31  3/27/2016 15:56  Business    Kissimmee          Orlando
# 279  3/28/2016 12:29  3/28/2016 12:42  Personal    Kissimmee          Orlando
# 282  3/29/2016 15:27  3/29/2016 16:11  Personal    Kissimmee          Orlando
# ...

# %%
df.loc[df['START*'].isin(cities)].sort_values(by='START*')
# Out:
#          START_DATE*        END_DATE* CATEGORY*       START*            STOP*  \
# 0     1/1/2016 21:11   1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1      1/2/2016 1:25    1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2     1/2/2016 20:25   1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3     1/5/2016 17:31   1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4     1/6/2016 14:42   1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
# 247  3/19/2016 17:17  3/19/2016 17:32  Business    Galveston     Port Bolivar
# 251  3/19/2016 19:33  3/19/2016 20:39  Business    Galveston          Houston
# 293    4/2/2016 8:48    4/2/2016 9:04  Personal    Kissimmee        Kissimmee
# 292   4/1/2016 16:52   4/1/2016 16:57  Personal    Kissimmee        Kissimmee
# 290   4/1/2016 14:36   4/1/2016 15:24  Business    Kissimmee          Orlando
# 289   4/1/2016 13:43   4/1/2016 14:01  Business    Kissimmee        Kissimmee
# ...

# %%
start_cities=['Fort Pierce','Galveston','Kissimmee']
stop_cities=['Houston','Orlando','Daytona Beach']
df.loc[ (df['START*'].isin(start_cities)) & (df['STOP*'].isin(stop_cities)) & (df['MILES*']>10) & (df['MILES*']<20) ]
# Out:
#          START_DATE*        END_DATE* CATEGORY*     START*    STOP*  MILES*  \
# 282  3/29/2016 15:27  3/29/2016 16:11  Personal  Kissimmee  Orlando    13.6
# 287  3/31/2016 12:47  3/31/2016 13:22  Business  Kissimmee  Orlando    16.1
# 290   4/1/2016 14:36   4/1/2016 15:24  Business  Kissimmee  Orlando    15.5
#
#            PURPOSE*
# 282             NaN
# 287  Temporary Site
# 290  Customer Visit

# %%
df.loc[df["START_DATE*"]=="Totals"]
# Out:
#      START_DATE* END_DATE* CATEGORY* START* STOP*   MILES* PURPOSE*
# 1155      Totals       NaN       NaN    NaN   NaN  12204.7      NaN

# %%
df['START_DATE*']=pd.to_datetime(df['START_DATE*'],format='%m/%d/%Y  %H:%M',errors='coerce')

# %%
df.loc[df['START_DATE*'].dt.month==1]
# Out:
#            START_DATE*        END_DATE* CATEGORY*       START*  \
# 0  2016-01-01 21:11:00   1/1/2016 21:17  Business  Fort Pierce
# 1  2016-01-02 01:25:00    1/2/2016 1:37  Business  Fort Pierce
# 2  2016-01-02 20:25:00   1/2/2016 20:38  Business  Fort Pierce
# 3  2016-01-05 17:31:00   1/5/2016 17:45  Business  Fort Pierce
# 4  2016-01-06 14:42:00   1/6/2016 15:49  Business  Fort Pierce
# ..                 ...              ...       ...          ...
# 56 2016-01-29 13:24:00  1/29/2016 13:47  Business       Durham
# 57 2016-01-29 18:31:00  1/29/2016 18:52  Business         Cary
# 58 2016-01-29 21:21:00  1/29/2016 21:40  Business         Apex
# 59 2016-01-30 16:21:00  1/30/2016 16:33  Business         Cary
# 60 2016-01-30 18:09:00  1/30/2016 18:24  Business         Apex
#
#               STOP*  MILES*         PURPOSE*
# 0       Fort Pierce     5.1   Meal/Entertain
# 1       Fort Pierce     5.0              NaN
# 2       Fort Pierce     4.8  Errand/Supplies
# ...

# %%
df['START_DATE*'][1]
# Out:
# Timestamp('2016-01-02 01:25:00')

# %%
# 1) Display all the records of jan-16 
df.loc[(df['START_DATE*'].dt.month==1)&(df['START_DATE*'].dt.year==2016)]
# Out:
#            START_DATE*        END_DATE* CATEGORY*       START*  \
# 0  2016-01-01 21:11:00   1/1/2016 21:17  Business  Fort Pierce
# 1  2016-01-02 01:25:00    1/2/2016 1:37  Business  Fort Pierce
# 2  2016-01-02 20:25:00   1/2/2016 20:38  Business  Fort Pierce
# 3  2016-01-05 17:31:00   1/5/2016 17:45  Business  Fort Pierce
# 4  2016-01-06 14:42:00   1/6/2016 15:49  Business  Fort Pierce
# ..                 ...              ...       ...          ...
# 56 2016-01-29 13:24:00  1/29/2016 13:47  Business       Durham
# 57 2016-01-29 18:31:00  1/29/2016 18:52  Business         Cary
# 58 2016-01-29 21:21:00  1/29/2016 21:40  Business         Apex
# 59 2016-01-30 16:21:00  1/30/2016 16:33  Business         Cary
# 60 2016-01-30 18:09:00  1/30/2016 18:24  Business         Apex
#
#               STOP*  MILES*         PURPOSE*
# 0       Fort Pierce     5.1   Meal/Entertain
# 1       Fort Pierce     5.0              NaN
# 2       Fort Pierce     4.8  Errand/Supplies
# ...

# %%
# 2) Display all the records of jan-16 and start city is  Cary
df1=df.loc[(df['START_DATE*'].dt.month==1)&(df['START_DATE*'].dt.year==2016) &(df["START*"]=='Cary')]
df1.reset_index(drop=True,inplace=True)

# %%
df1
# Out:
#            START_DATE*           END_DATE* CATEGORY* START*        STOP*  \
# 0  2016-01-07 13:27:00 2016-01-07 13:33:00  Business   Cary         Cary
# 1  2016-01-10 08:05:00 2016-01-10 08:25:00  Business   Cary  Morrisville
# 2  2016-01-15 11:43:00 2016-01-15 12:03:00  Business   Cary       Durham
# 3  2016-01-18 14:55:00 2016-01-18 15:06:00  Business   Cary         Cary
# 4  2016-01-20 10:36:00 2016-01-20 11:11:00  Business   Cary      Raleigh
# 5  2016-01-21 14:25:00 2016-01-21 14:29:00  Business   Cary         Cary
# 6  2016-01-21 14:43:00 2016-01-21 14:51:00  Business   Cary         Cary
# 7  2016-01-21 16:01:00 2016-01-21 16:06:00  Business   Cary         Cary
# 8  2016-01-26 17:17:00 2016-01-26 17:22:00  Business   Cary         Cary
# 9  2016-01-26 17:27:00 2016-01-26 17:29:00  Business   Cary         Cary
# 10 2016-01-27 09:24:00 2016-01-27 09:31:00  Business   Cary         Cary
# 11 2016-01-27 10:19:00 2016-01-27 10:48:00  Business   Cary      Raleigh
# ...

# %%
df['CATEGORY*'].value_counts()
# Out:
# CATEGORY*
# Business    1078
# Personal      77
# Name: count, dtype: int64

# %%
# df.drop([1155],inplace=True)
df['END_DATE*']=pd.to_datetime(df['END_DATE*'],format='%m/%d/%Y  %H:%M',errors='coerce')

# %%
df.tail()
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
# 1155                 NaT                 NaT       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
df.sort_values(by=['MILES*'],ascending=[False])
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 1155                 NaT                 NaT       NaN               NaN
# 269  2016-03-25 16:52:00 2016-03-25 22:22:00  Business             Latta
# 270  2016-03-25 22:54:00 2016-03-26 01:39:00  Business      Jacksonville
# 881  2016-10-30 15:22:00 2016-10-30 18:23:00  Business         Asheville
# 776  2016-09-27 21:01:00 2016-09-28 02:37:00  Business  Unknown Location
# ...                  ...                 ...       ...               ...
# 1121 2016-12-27 12:53:00 2016-12-27 12:57:00  Business           Kar?chi
# 1110 2016-12-24 22:04:00 2016-12-24 22:09:00  Business            Lahore
# 44   2016-01-26 17:27:00 2016-01-26 17:29:00  Business              Cary
# 420  2016-06-08 17:16:00 2016-06-08 17:18:00  Business              Soho
# 120  2016-02-17 16:38:00 2016-02-17 16:43:00  Business        Katunayaka
#
#                  STOP*   MILES*         PURPOSE*
# ...

# %%
df.sort_values(by=['MILES*','START*'],ascending=[False,True])
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 1155                 NaT                 NaT       NaN               NaN
# 269  2016-03-25 16:52:00 2016-03-25 22:22:00  Business             Latta
# 270  2016-03-25 22:54:00 2016-03-26 01:39:00  Business      Jacksonville
# 881  2016-10-30 15:22:00 2016-10-30 18:23:00  Business         Asheville
# 776  2016-09-27 21:01:00 2016-09-28 02:37:00  Business  Unknown Location
# ...                  ...                 ...       ...               ...
# 1111 2016-12-25 00:10:00 2016-12-25 00:14:00  Business            Lahore
# 516  2016-07-05 16:48:00 2016-07-05 16:52:00  Business       Whitebridge
# 44   2016-01-26 17:27:00 2016-01-26 17:29:00  Business              Cary
# 120  2016-02-17 16:38:00 2016-02-17 16:43:00  Business        Katunayaka
# 420  2016-06-08 17:16:00 2016-06-08 17:18:00  Business              Soho
#
#                  STOP*   MILES*         PURPOSE*
# ...

# %%
import numpy as np

# %%
df['MILES_CAT']=np.where( df["MILES*"] >100, "Long trip","Short trip" )

# %%
df.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES*         PURPOSE*   MILES_CAT  MILES_CAT1
# 0      Fort Pierce     5.1   Meal/Entertain  Short trip  Short trip
# 1      Fort Pierce     5.0              NaN  Short trip  Short trip
# 2      Fort Pierce     4.8  Errand/Supplies  Short trip  Short trip
# 3      Fort Pierce     4.7          Meeting  Short trip  Short trip
# 4  West Palm Beach    63.7   Customer Visit  Short trip  Short trip

# %%
# %%timeit
df['MILES_CAT1']=np.where( df["MILES*"] <200, np.where(df["MILES*"] >100,'Medium trip','Short trip' ),"Long trip" )
# Out:
# 212 µs ± 638 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
df.sort_values(by=['MILES_CAT1'],ascending=[False])
# Out:
#             START_DATE*           END_DATE* CATEGORY*            START*  \
# 0   2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 765 2016-09-19 16:23:00 2016-09-19 16:31:00  Business         Islamabad
# 771 2016-09-24 14:34:00 2016-09-24 15:15:00  Business           Karachi
# 770 2016-09-23 13:15:00 2016-09-23 13:40:00  Business           Karachi
# 769 2016-09-20 20:47:00 2016-09-20 22:47:00  Business  Unknown Location
# ..                  ...                 ...       ...               ...
# 298 2016-04-02 23:11:00 2016-04-03 01:34:00  Business         Ridgeland
# 299 2016-04-03 02:00:00 2016-04-03 04:16:00  Business          Florence
# 776 2016-09-27 21:01:00 2016-09-28 02:37:00  Business  Unknown Location
# 559 2016-07-17 12:20:00 2016-07-17 15:25:00  Personal             Boone
# 546 2016-07-14 16:39:00 2016-07-14 20:05:00  Business       Morrisville
#
#                 STOP*  MILES*        PURPOSE*   MILES_CAT   MILES_CAT1
# ...

# %%
# %%timeit
conditions=[ 
    (df["MILES*"] >100),
    (df["MILES*"]>50 ) &(df["MILES*"] <=100),
    (df["MILES*"]<=50)
]
cat=['Long trip','Medium trip', 'Short trip']
df['MILES_CAT1']=np.select(conditions,cat,default='Unknown')
# Out:
# 356 µs ± 7.63 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
df
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
# 1155                 NaT                 NaT       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*   MILES_CAT   MILES_CAT1
# ...
